# %%
import sentencepiece as spm

# %%
spm.SentencePieceTrainer.train(input='C:/Users/menon/mini-gpt/data/input.txt',model_prefix='C:/Users/menon/mini-gpt/tokenizer/tokenizer',vocab_size=8000,model_type='bpe',character_coverage=1.0,pad_id=0,unk_id=1,bos_id=2,eos_id=3)

# %%
print("✓ Tokenizer trained successfully!")
print("  - tokenizer/tokenizer.model")
print("  - tokenizer/tokenizer.vocab")
# Out:
# ✓ Tokenizer trained successfully!
#   - tokenizer/tokenizer.model
#   - tokenizer/tokenizer.vocab
